# %% [markdown]
# # Using the autocorrelation function to find a periodic signal

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# use seaborn for matplotlib settings
import seaborn; seaborn.set()

# %% [markdown]
# ## The Data
# Exmple data will be Q1-Q15 photometry of KOI-63. We're using Kepler data as the example because the straight-up ACF requires evenly-sampled data.  This data is pre-conditioned to have no gaps (gaps have been set to zero).

# %%
data = np.load('koi63.npy')
t, y = (data[:,0], data[:,1])

fig, ax = plt.subplots()
ax.plot(t, y, 'o', ms=0.5);
ax.set_xlabel('MJD')
ax.set_ylabel('flux')
ax.set_title('KOI-63');

# %%
# add up-directory to Python path
import sys, os; sys.path.append(os.path.abspath('..'))
from periodogram.acf import ACF
# Out:
# /Users/tdm/anaconda/lib/python2.7/site-packages/astroML/time_series/periodogram.py:8: UserWarning: Using slow version of lomb_scargle. Install astroML_addons to use an optimized version
#   warnings.warn("Using slow version of lomb_scargle. Install astroML_addons "

# %%
model = ACF(maxlag=30).fit(t,y)
model_EK = ACF(maxlag=30, method='EK').fit(t,y)

periods = np.linspace(0.1, 30, 1000)
scores = model.score(periods)
scores_EK = model_EK.score(periods)

plt.plot(periods, scores, label='standard');
plt.plot(periods, scores_EK, label='EK')

plt.legend()

# %%
model.period_search()
# Out:
# 5.2718590692384169
